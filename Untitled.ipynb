# %%
import matplotlib
# %matplotlib inline
import matplotlib.pyplot as plt

import csv
import numpy

#with open('test_data31.csv', 'r') as csvfile:
data = numpy.genfromtxt('ECGdata/test_data1.csv', delimiter = ',')
time = data[:,0]
voltage = data[:,1]
#print(data)
print(time)
print(voltage)

plt.plot(time,voltage)

#with open('ECGdata/samples.csv', 'r') as csvfile:
    #csvfile = csvfile.readlines()
    #test_data1 = csv.reader(csvfile, delimiter = ',')
    #time = test_data1[:,0]
    #print(time)
    #for i in test_data1:
        #print(i)
        #j.replace('"', '')
        #m, s = i[0].split(':')
        #sec = 60*m + s
        #x.append(float(sec))
        #y.append(float(j[1]))

#plt.figure(1)
#plt.plot(x,y)
#plt.show()
# Out:
# [0.0000e+00 3.0000e-03 6.0000e-03 ... 2.7769e+01 2.7772e+01 2.7775e+01]
# [-0.145 -0.145 -0.145 ...  0.71   0.795  0.72 ]
